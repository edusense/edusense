# %%
import numpy as np
import pandas as pd
import scipy.stats

pd.options.mode.chained_assignment = None
from matplotlib import pyplot as plt, rcParams
# import cv2
import seaborn as sns

sns.set(style="white", context="paper")
from cycler import cycler
import os, sys
import glob
from datetime import datetime, timedelta
from itertools import combinations
import base64
from PIL import Image
from io import BytesIO as _BytesIO
import requests
import json
import pickle
from datetime import datetime
from IPython.display import display, Markdown, Latex
from sklearn.metrics import *
import collections
from copy import deepcopy
import traceback
# import plotly
# from pandas_profiling import ProfileReport

pd.options.display.max_columns = None


def printm(s): return display(Markdown(s))
# Out:
# /home/prasoon/anaconda3/envs/edusense/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Figure out how many sessions are there, and how many frames for each session

# %%
track_analysis_meta_cache = '../cache/analysis_tracking/meta_info'
os.makedirs(track_analysis_meta_cache,exist_ok=True)

# %%
base_dir = '/mnt/ci-nas-cache/edulyzeV2/track/'
frame_file_data = {}
for course_idx, course_dir in enumerate(glob.glob(f"{base_dir}/*")):
    course_name = course_dir.split("/")[-1]
    course_cache_file = f"{track_analysis_meta_cache}/{course_name}"
    if os.path.exists(course_cache_file):
        frame_file_data[course_name] = pickle.load(open(course_cache_file,"rb"))
        continue
    frame_file_data[course_name]={}
        
    for session_idx, session_dir in enumerate(glob.glob(f"{course_dir}/*")):
        session_name = session_dir.split("/")[-1]
        frame_file_data[course_name][session_name] = {}
        frame_files = glob.glob(f"{session_dir}/*")
        frame_file_names = [xr.split("/")[-1] for xr in frame_files]
        if 'end.pb' in frame_file_names:
            frame_file_data[course_name][session_name]['is_completed']=True
        else:
            frame_file_data[course_name][session_name]['is_completed']=False            
        frame_ids = [int(xr.split(".")[0]) for xr in frame_file_names if not (xr=='end.pb')]
        frame_file_data[course_name][session_name]['frame_ids'] = sorted(frame_ids)
        frame_file_data[course_name][session_name]['dir_location'] = session_dir
        print(f"Got metadata for course: {course_idx}-{course_name}, session:{session_idx}-{session_name}")
    pickle.dump(frame_file_data[course_name],open(course_cache_file,"wb"))

# %%
frame_file_data.keys()
# Out:
# dict_keys(['17214A', '17214B', '17214C', '05391A', '05410A', '6485A', '17214E', '17214D', '21127J', '21127L', '15819AA', '18715A', '79240A', '82119A', '24352A', '24352B', '24352C', '6705A', '9403A', '19603A', '79388A', '86375A', '9214L', '09217S', '15424A', '15740A', '19646B1', '82235A', '12411B', '17213E', '05682A', '09105S', '21122S', '21260S', '36200S', '57173S', '73102S', '76270S', '79201S', '82101S', '82271S', '05410B', '05418A', '05681A', '05748A', '05772A', '09105A', '09105C', '09105D', '15251C', '15251I', '17346A', '17356A', '21127H', '17356L1'])

# %%
# course_name, session_name, is_completed, min_frame, max_frame_number, num_frames, session_duration_mins, 
# Next step: Get how many sessions are completed, and 
session_infos = []
for course_name in frame_file_data:
    session_meta_data = {'course':course_name}
    for session_name in frame_file_data[course_name]:
        # print(session_name)
        session_meta_data['session']=session_name.split("-front")[0]
        try:
            session_meta_data['start_time'] = pd.to_datetime(session_meta_data['session'].split("_")[-1], format="%Y%m%d%H%M")
        except:
            session_meta_data['start_time'] = pd.to_datetime(session_meta_data['session'].split("_")[-1], format="%Y%m%d%H%M%S")
        session_meta_data['start_hour'] = session_meta_data['start_time'].strftime('%H:%M')
        session_meta_data['classroom'] = "_".join(session_meta_data['session'].split("_")[-3:-1])
        meta_data = frame_file_data[course_name][session_name]
        session_meta_data['completed'] = meta_data['is_completed']
        session_meta_data['num_frames'] = len(meta_data['frame_ids'])
        if len(meta_data['frame_ids']) > 0:
            session_meta_data['max_frame'] = max(meta_data['frame_ids'])
            session_meta_data['duration_in_mins'] = max(meta_data['frame_ids'])//(15*60)
        session_infos.append(session_meta_data)
        # print(course_name, session_name)
df_session_info = pd.DataFrame(session_infos)

# %%
session_infos[-1]
# Out:
# {'course': '17356L1',
#  'session': 'classinsight-cmu_17356L1_weh_5302_201905021030',
#  'start_time': Timestamp('2019-05-02 10:30:00'),
#  'start_hour': '10:30',
#  'classroom': 'weh_5302',
#  'completed': True,
#  'num_frames': 23999,
#  'max_frame': 71994,
#  'duration_in_mins': 79}

# %%
df_session_info.head()
# Out:
#    course                                       session          start_time  \
# 0  17214A  classinsight-cmu_17214A_dh_2105_201905010930 2019-05-01 09:30:00
# 1  17214A  classinsight-cmu_17214A_dh_2105_201905010930 2019-05-01 09:30:00
# 2  17214A  classinsight-cmu_17214A_dh_2105_201905010930 2019-05-01 09:30:00
# 3  17214A  classinsight-cmu_17214A_dh_2105_201905010930 2019-05-01 09:30:00
# 4  17214A  classinsight-cmu_17214A_dh_2105_201905010930 2019-05-01 09:30:00
#
#   start_hour classroom  completed  num_frames  max_frame  duration_in_mins
# 0      09:30   dh_2105      False           0        NaN               NaN
# 1      09:30   dh_2105      False           0        NaN               NaN
# 2      09:30   dh_2105      False           0        NaN               NaN
# 3      09:30   dh_2105      False           0        NaN               NaN
# 4      09:30   dh_2105      False           0        NaN               NaN

# %%
df_session_info = df_session_info[df_session_info.completed]
df_session_info['course_num'] = df_session_info.course.apply(lambda x: int(x[:5]) if len(x)>5 else int(x[:4]))
df_session_info['course_num'].value_counts()
# Out:
# 9105     104
# 21127     85
# 5410      56
# 6705      41
# 24352     40
# 17356     37
# 17214     36
# 5748      28
# 5418      27
# 5391      27
# 15251     26
# 76270     20
# 82271     17
# 21260     16
# 5681      15
# 73102     14
# 79201     14
# 9214      13
# 15424     13
# 57173     13
# 36200     10
# 15740     10
# 9403      10
# 82235      9
# 5772       8
# 6485       6
# 79388      6
# 86375      5
# 17346      5
# 12411      4
# 19646      3
# 17213      1
# Name: course_num, dtype: int64

# %% [markdown]
# # Include course meta info

# %%
df_course_info = pd.read_csv('course_descriptions_1.csv')
df_course_info2 = pd.read_csv('course_descriptions_2.csv')
df_course_info = pd.concat([df_course_info,df_course_info2],ignore_index=True)
df_course_info = df_course_info[~df_course_info.course_name.isnull()]
df_course_info.info()
df_course_info.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 0 to 64
# Data columns (total 19 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   S.No                                                 63 non-null     int64
#  1   Semester                                             51 non-null     object
#  2   Division                                             51 non-null     object
#  3   Dept                                                 51 non-null     object
#  4   course_num                                           63 non-null     int64
#  5   course_name                                          63 non-null     object
#  6   Course Level                                         51 non-null     object
#  7   Hrs Per Week                                         51 non-null     float64
#  8   course_category                                      62 non-null     object
#  9   description                                          63 non-null     object
#  10  Interest in student learning                         51 non-null     float64
#  11  Clearly explain course requirements                  51 non-null     float64
#  12  Clear learning objectives & goals                    51 non-null     float64
#  13  Instructor provides feedback to students to improve  51 non-null     float64
#  14  Demonstrate importance of subject matter             51 non-null     float64
#  15  Explains subject matter of course                    51 non-null     float64
#  16  Show respect for all students                        51 non-null     float64
#  17  Overall teaching rate                                51 non-null     float64
#  18  Overall course rate                                  51 non-null     float64
# dtypes: float64(10), int64(2), object(7)
# memory usage: 9.8+ KB
#    S.No Semester                          Division Dept  course_num  \
# 0     1     Fall  Carnegie Institute of Technology  CHE        6705
# 1     2     Fall         Mellon College of Science  CMY        9214
# 2     3     Fall         Mellon College of Science  CMY        9403
# 3     4     Fall  Carnegie Institute of Technology  CEE       12411
# 4     5     Fall        School of Computer Science   CS       15251
#
#             course_name   Course Level  Hrs Per Week course_category  \
# 0   ADV CHE THRMODYNMCS       Graduate          8.16          theory
# 1    PHYSICAL CHEMISTRY  Undergraduate          6.50          theory
# 2             CMY ADDIC  Undergraduate          5.75          theory
# 3  PRJ MANGMT CONSTRCTN  Undergraduate          7.46         applied
# 4  GRT IDEAS THERTCL CS  Undergraduate         14.27          theory
#
#                                          description  \
# 0  Advanced application of the general thermodyna...
# 1  This is a one-semester course intended primari...
# 2  What makes us need something so much that it e...
# 3  Through planning and management, and optimizat...
# 4  This course is about how to use theoretical id...
#
#    Interest in student learning  Clearly explain course requirements  \
# 0                          4.42                                 4.63
# 1                          5.00                                 4.50
# 2                          5.00                                 4.75
# 3                          4.34                                 3.98
# 4                          4.71                                 4.69
#
#    Clear learning objectives & goals  \
# 0                               4.74
# 1                               4.50
# 2                               5.00
# 3                               4.05
# 4                               4.72
#
#    Instructor provides feedback to students to improve  \
# 0                                               4.05
# 1                                               4.50
# 2                                               5.00
# 3                                               3.89
# 4                                               4.53
#
#    Demonstrate importance of subject matter  \
# 0                                      4.58
# 1                                      5.00
# 2                                      5.00
# 3                                      4.48
# 4                                      4.72
#
#    Explains subject matter of course  Show respect for all students  \
# 0                               4.63                           4.95
# 1                               4.50                           5.00
# 2                               4.88                           5.00
# 3                               4.02                           4.69
# 4                               4.72                           4.81
#
#    Overall teaching rate  Overall course rate
# 0                   4.47                 4.37
# 1                   4.50                 4.50
# 2                   5.00                 4.88
# 3                   3.98                 3.72
# 4                   4.67                 4.72

# %%
df_session_info = pd.merge(df_session_info, df_course_info, on=['course_num'])

# %%
df_session_info.head()
# Out:
#    course                                      session          start_time  \
# 0  17214B  classinsight-cmu_17214B_ph_a21_201905011030 2019-05-01 10:30:00
# 1  17214B  classinsight-cmu_17214B_ph_a21_201905011030 2019-05-01 10:30:00
# 2  17214B  classinsight-cmu_17214B_ph_a21_201905011030 2019-05-01 10:30:00
# 3  17214B  classinsight-cmu_17214B_ph_a21_201905011030 2019-05-01 10:30:00
# 4  17214B  classinsight-cmu_17214B_ph_a21_201905011030 2019-05-01 10:30:00
#
#   start_hour classroom  completed  num_frames  max_frame  duration_in_mins  \
# 0      10:30    ph_a21       True       14999    44994.0              49.0
# 1      10:30    ph_a21       True       14999    44994.0              49.0
# 2      10:30    ph_a21       True       14999    44994.0              49.0
# 3      10:30    ph_a21       True       14999    44994.0              49.0
# 4      10:30    ph_a21       True       14999    44994.0              49.0
#
#    course_num  S.No Semester                    Division Dept  \
# 0       17214     9     Fall  School of Computer Science  ISR
# 1       17214    28   Spring  School of Computer Science   SE
# 2       17214     9     Fall  School of Computer Science  ISR
# 3       17214    28   Spring  School of Computer Science   SE
# 4       17214     9     Fall  School of Computer Science  ISR
#
#             course_name   Course Level  Hrs Per Week course_category  \
# 0  PRIN 0-0 SFTWR CONST  Undergraduate         14.51         applied
# 1  PRIN 0-0 SFTWR CONST  Undergraduate         13.09         applied
# 2  PRIN 0-0 SFTWR CONST  Undergraduate         14.51         applied
# 3  PRIN 0-0 SFTWR CONST  Undergraduate         13.09         applied
# 4  PRIN 0-0 SFTWR CONST  Undergraduate         14.51         applied
#
#                                          description  \
# 0  Software engineers today are less likely to de...
# 1  Software engineers today are less likely to de...
# 2  Software engineers today are less likely to de...
# 3  Software engineers today are less likely to de...
# 4  Software engineers today are less likely to de...
#
#    Interest in student learning  Clearly explain course requirements  \
# 0                          4.27                                 4.24
# 1                          4.39                                 4.18
# 2                          4.27                                 4.24
# 3                          4.39                                 4.18
# 4                          4.27                                 4.24
#
#    Clear learning objectives & goals  \
# 0                               4.38
# 1                               4.48
# 2                               4.38
# 3                               4.48
# 4                               4.38
#
#    Instructor provides feedback to students to improve  \
# 0                                               4.04
# 1                                               3.88
# 2                                               4.04
# 3                                               3.88
# 4                                               4.04
#
#    Demonstrate importance of subject matter  \
# 0                                      4.36
# 1                                      4.51
# 2                                      4.36
# 3                                      4.51
# 4                                      4.36
#
#    Explains subject matter of course  Show respect for all students  \
# 0                               4.16                           4.40
# 1                               4.38                           4.86
# 2                               4.16                           4.40
# 3                               4.38                           4.86
# 4                               4.16                           4.40
#
#    Overall teaching rate  Overall course rate
# 0                   4.13                 4.13
# 1                   4.26                 4.26
# 2                   4.13                 4.13
# 3                   4.26                 4.26
# 4                   4.13                 4.13

# %%
df_session_info[df_session_info.course=='21127L']
# Out:
#      course                                      session          start_time  \
# 239  21127L  classinsight-cmu_21127L_ph_a22_201905021630 2019-05-02 16:30:00
# 240  21127L  classinsight-cmu_21127L_ph_a22_201905021630 2019-05-02 16:30:00
# 241  21127L  classinsight-cmu_21127L_ph_a22_201905021630 2019-05-02 16:30:00
# 242  21127L  classinsight-cmu_21127L_ph_a22_201905021630 2019-05-02 16:30:00
# 243  21127L  classinsight-cmu_21127L_ph_a22_201905021630 2019-05-02 16:30:00
# ..      ...                                          ...                 ...
# 318  21127L  classinsight-cmu_21127L_ph_a22_201905021630 2019-05-02 16:30:00
# 319  21127L  classinsight-cmu_21127L_ph_a22_201905021630 2019-05-02 16:30:00
# 320  21127L  classinsight-cmu_21127L_ph_a22_201905021630 2019-05-02 16:30:00
# 321  21127L  classinsight-cmu_21127L_ph_a22_201905021630 2019-05-02 16:30:00
# 322  21127L  classinsight-cmu_21127L_ph_a22_201905021630 2019-05-02 16:30:00
#
#     start_hour classroom  completed  num_frames  max_frame  duration_in_mins  \
# 239      16:30    ph_a22       True       14999    44994.0              49.0
# 240      16:30    ph_a22       True       14999    44994.0              49.0
# 241      16:30    ph_a22       True       14999    44994.0              49.0
# 242      16:30    ph_a22       True       14999    44994.0              49.0
# 243      16:30    ph_a22       True       14999    44994.0              49.0
# ..         ...       ...        ...         ...        ...               ...
# 318      16:30    ph_a22       True       14999    44994.0              49.0
# 319      16:30    ph_a22       True       14999    44994.0              49.0
# 320      16:30    ph_a22       True       14999    44994.0              49.0
# 321      16:30    ph_a22       True       14999    44994.0              49.0
# 322      16:30    ph_a22       True       14999    44994.0              49.0
#
#      course_num  S.No Semester                   Division Dept  \
# 239       21127    13     Fall  Mellon College of Science  MSC
# 240       21127    31   Spring  Mellon College of Science  MSC
# 241       21127    42   Summer  Mellon College of Science  MSC
# 242       21127    13     Fall  Mellon College of Science  MSC
# 243       21127    31   Spring  Mellon College of Science  MSC
# ..          ...   ...      ...                        ...  ...
# 318       21127    31   Spring  Mellon College of Science  MSC
# 319       21127    42   Summer  Mellon College of Science  MSC
# 320       21127    13     Fall  Mellon College of Science  MSC
# 321       21127    31   Spring  Mellon College of Science  MSC
# 322       21127    42   Summer  Mellon College of Science  MSC
#
#               course_name   Course Level  Hrs Per Week course_category  \
# 239  CONCEPTS OF MATHMTCS  Undergraduate         12.60          theory
# 240  CONCEPTS OF MATHMTCS  Undergraduate         11.17          theory
# 241  CONCEPTS OF MATHMTCS  Undergraduate         17.12          theory
# 242  CONCEPTS OF MATHMTCS  Undergraduate         12.60          theory
# 243  CONCEPTS OF MATHMTCS  Undergraduate         11.17          theory
# ..                    ...            ...           ...             ...
# 318  CONCEPTS OF MATHMTCS  Undergraduate         11.17          theory
# 319  CONCEPTS OF MATHMTCS  Undergraduate         17.12          theory
# 320  CONCEPTS OF MATHMTCS  Undergraduate         12.60          theory
# 321  CONCEPTS OF MATHMTCS  Undergraduate         11.17          theory
# 322  CONCEPTS OF MATHMTCS  Undergraduate         17.12          theory
#
#                                            description  \
# 239  This course introduces the basic concepts, ide...
# 240  This course introduces the basic concepts, ide...
# 241  This course introduces the basic concepts, ide...
# 242  This course introduces the basic concepts, ide...
# 243  This course introduces the basic concepts, ide...
# ..                                                 ...
# 318  This course introduces the basic concepts, ide...
# 319  This course introduces the basic concepts, ide...
# 320  This course introduces the basic concepts, ide...
# 321  This course introduces the basic concepts, ide...
# 322  This course introduces the basic concepts, ide...
#
#      Interest in student learning  Clearly explain course requirements  \
# 239                          4.04                                 4.27
# 240                          4.34                                 4.42
# 241                          4.76                                 4.76
# 242                          4.04                                 4.27
# 243                          4.34                                 4.42
# ..                            ...                                  ...
# 318                          4.34                                 4.42
# 319                          4.76                                 4.76
# 320                          4.04                                 4.27
# 321                          4.34                                 4.42
# 322                          4.76                                 4.76
#
#      Clear learning objectives & goals  \
# 239                               4.25
# 240                               4.37
# 241                               4.82
# 242                               4.25
# 243                               4.37
# ..                                 ...
# 318                               4.37
# 319                               4.82
# 320                               4.25
# 321                               4.37
# 322                               4.82
#
#      Instructor provides feedback to students to improve  \
# 239                                               3.73
# 240                                               3.98
# 241                                               4.41
# 242                                               3.73
# 243                                               3.98
# ..                                                 ...
# 318                                               3.98
# 319                                               4.41
# 320                                               3.73
# 321                                               3.98
# 322                                               4.41
#
#      Demonstrate importance of subject matter  \
# 239                                      4.05
# 240                                      4.33
# 241                                      4.79
# 242                                      4.05
# 243                                      4.33
# ..                                        ...
# 318                                      4.33
# 319                                      4.79
# 320                                      4.05
# 321                                      4.33
# 322                                      4.79
#
#      Explains subject matter of course  Show respect for all students  \
# 239                               4.16                           4.15
# 240                               4.31                           4.56
# 241                               4.79                           4.68
# 242                               4.16                           4.15
# 243                               4.31                           4.56
# ..                                 ...                            ...
# 318                               4.31                           4.56
# 319                               4.79                           4.68
# 320                               4.16                           4.15
# 321                               4.31                           4.56
# 322                               4.79                           4.68
#
#      Overall teaching rate  Overall course rate
# 239                   4.06                 3.92
# 240                   4.29                 4.18
# 241                   4.76                 4.62
# 242                   4.06                 3.92
# 243                   4.29                 4.18
# ..                     ...                  ...
# 318                   4.29                 4.18
# 319                   4.76                 4.62
# 320                   4.06                 3.92
# 321                   4.29                 4.18
# 322                   4.76                 4.62
#
# [84 rows x 28 columns]

# %%
df_course_info = df_session_info.groupby(['course','Semester','Course Level','course_category','Division','start_hour']).agg({
    'completed':'count',
    'duration_in_mins':['min','mean','max'],
    'num_frames':['min','mean','max'],}).reset_index()
df_course_info.columns = ['course','Semester','Course Level','course_category','Division','start_hour','num_sessions','dur_min','dur_mean','dur_max','frame_count_min','frame_count_mean','frame_count_max']
df_course_info= df_course_info[df_course_info.dur_mean > 25]
df_course_info.sort_values(by='start_hour',ascending=False).reset_index(drop=True)
# Out:
#      course Semester   Course Level course_category  \
# 0    21127L   Summer  Undergraduate          theory
# 1    21127L   Spring  Undergraduate          theory
# 2    21127L     Fall  Undergraduate          theory
# 3    24352C   Spring  Undergraduate         applied
# 4    24352C     Fall  Undergraduate         applied
# 5    24352B   Spring  Undergraduate         applied
# 6    24352B     Fall  Undergraduate         applied
# 7    24352A   Spring  Undergraduate         applied
# 8    17214E     Fall  Undergraduate         applied
# 9    17214E   Spring  Undergraduate         applied
# 10   24352A     Fall  Undergraduate         applied
# 11   17356A   Spring  Undergraduate         applied
# 12   15424A     Fall  Undergraduate         applied
# 13   79201S   Summer  Undergraduate          theory
# 14   79201S   Spring  Undergraduate          theory
# 15   15251C     Fall  Undergraduate          theory
# 16   17214C   Spring  Undergraduate         applied
# 17   17214C     Fall  Undergraduate         applied
# 18   15251C   Spring  Undergraduate         applied
# 19  17356L1   Spring  Undergraduate         applied
# 20   17214B   Spring  Undergraduate         applied
# 21   17214B     Fall  Undergraduate         applied
# 22    9403A     Fall  Undergraduate          theory
# 23   82271S   Summer  Undergraduate        language
# 24   82271S   Spring  Undergraduate        language
# 25   82271S     Fall  Undergraduate        language
# 26   36200S     Fall  Undergraduate         applied
# 27   36200S   Spring  Undergraduate         applied
# 28   36200S   Summer  Undergraduate         applied
# 29   21260S   Spring  Undergraduate          theory
# 30   21260S     Fall  Undergraduate          theory
# 31   21260S   Summer  Undergraduate          theory
# 32   73102S     Fall  Undergraduate          theory
# 33   73102S   Spring  Undergraduate          theory
# 34   73102S   Summer  Undergraduate          theory
# 35   15251I   Spring  Undergraduate         applied
# 36   15251I     Fall  Undergraduate          theory
# 37   21127J     Fall  Undergraduate          theory
# 38   21127J   Spring  Undergraduate          theory
# 39   21127J   Summer  Undergraduate          theory
# 40   57173S     Fall  Undergraduate          theory
# 41   57173S   Summer  Undergraduate          theory
#
#                                              Division start_hour  \
# 0                           Mellon College of Science      16:30
# 1                           Mellon College of Science      16:30
# 2                           Mellon College of Science      16:30
# 3                    Carnegie Institute of Technology      15:30
# 4                    Carnegie Institute of Technology      15:30
# 5                    Carnegie Institute of Technology      14:30
# 6                    Carnegie Institute of Technology      14:30
# 7                    Carnegie Institute of Technology      13:30
# 8                          School of Computer Science      13:30
# 9                          School of Computer Science      13:30
# 10                   Carnegie Institute of Technology      13:30
# 11                         School of Computer Science      12:30
# 12                         School of Computer Science      12:00
# 13  Dietrich College of Humanities and Social Scie...      11:56
# 14  Dietrich College of Humanities and Social Scie...      11:56
# 15                         School of Computer Science      11:30
# 16                         School of Computer Science      11:30
# 17                         School of Computer Science      11:30
# 18                         School of Computer Science      11:30
# 19                         School of Computer Science      10:30
# 20                         School of Computer Science      10:30
# 21                         School of Computer Science      10:30
# 22                          Mellon College of Science      10:29
# 23  Dietrich College of Humanities and Social Scie...      10:28
# 24  Dietrich College of Humanities and Social Scie...      10:28
# 25  Dietrich College of Humanities and Social Scie...      10:28
# 26  Dietrich College of Humanities and Social Scie...      10:27
# 27  Dietrich College of Humanities and Social Scie...      10:27
# 28  Dietrich College of Humanities and Social Scie...      10:27
# 29                          Mellon College of Science      10:26
# 30                          Mellon College of Science      10:26
# 31                          Mellon College of Science      10:26
# 32  Dietrich College of Humanities and Social Scie...      10:25
# 33  Dietrich College of Humanities and Social Scie...      10:25
# 34  Dietrich College of Humanities and Social Scie...      10:25
# 35                         School of Computer Science      09:30
# 36                         School of Computer Science      09:30
# 37                          Mellon College of Science      09:30
# 38                          Mellon College of Science      09:30
# 39                          Mellon College of Science      09:30
# 40                               College of Fine Arts      08:30
# 41                               College of Fine Arts      08:30
#
#     num_sessions  dur_min  dur_mean  dur_max  frame_count_min  \
# 0             28     49.0      49.0     49.0            14999
# 1             28     49.0      49.0     49.0            14999
# 2             28     49.0      49.0     49.0            14999
# 3             14     49.0      49.0     49.0            14997
# 4             14     49.0      49.0     49.0            14997
# 5             14     49.0      49.0     49.0            14999
# 6             14     49.0      49.0     49.0            14999
# 7             12     49.0      49.0     49.0            14998
# 8             14     49.0      49.0     49.0            14999
# 9             14     49.0      49.0     49.0            14999
# 10            12     49.0      49.0     49.0            14998
# 11             9     45.0      45.0     45.0            13732
# 12            13     79.0      79.0     79.0            23958
# 13            14     79.0      79.0     79.0            23996
# 14            14     79.0      79.0     79.0            23996
# 15            13     49.0      49.0     49.0            14999
# 16            11     49.0      49.0     49.0            14998
# 17            11     49.0      49.0     49.0            14998
# 18            13     49.0      49.0     49.0            14999
# 19            28     79.0      79.0     79.0            23999
# 20            11     49.0      49.0     49.0            14999
# 21            11     49.0      49.0     49.0            14999
# 22            10     50.0      50.0     50.0            15203
# 23            17     79.0      79.0     79.0            23999
# 24            17     79.0      79.0     79.0            23999
# 25            17     79.0      79.0     79.0            23999
# 26            10     79.0      79.0     79.0            23998
# 27            10     79.0      79.0     79.0            23998
# 28            10     79.0      79.0     79.0            23998
# 29            16     79.0      79.0     79.0            24000
# 30            16     79.0      79.0     79.0            24000
# 31            16     79.0      79.0     79.0            24000
# 32            14     79.0      79.0     79.0            23998
# 33            14     79.0      79.0     79.0            23998
# 34            14     79.0      79.0     79.0            23998
# 35            13     49.0      49.0     49.0            14998
# 36            13     49.0      49.0     49.0            14998
# 37            28     49.0      49.0     49.0            14998
# 38            28     49.0      49.0     49.0            14998
# 39            28     49.0      49.0     49.0            14998
# 40            13     47.0      47.0     47.0            14399
# 41            13     47.0      47.0     47.0            14399
#
#     frame_count_mean  frame_count_max
# 0            14999.0            14999
# 1            14999.0            14999
# 2            14999.0            14999
# 3            14997.0            14997
# 4            14997.0            14997
# 5            14999.0            14999
# 6            14999.0            14999
# 7            14998.0            14998
# 8            14999.0            14999
# 9            14999.0            14999
# 10           14998.0            14998
# 11           13732.0            13732
# 12           23958.0            23958
# 13           23996.0            23996
# 14           23996.0            23996
# 15           14999.0            14999
# 16           14998.0            14998
# 17           14998.0            14998
# 18           14999.0            14999
# 19           23999.0            23999
# 20           14999.0            14999
# 21           14999.0            14999
# 22           15203.0            15203
# 23           23999.0            23999
# 24           23999.0            23999
# 25           23999.0            23999
# 26           23998.0            23998
# 27           23998.0            23998
# 28           23998.0            23998
# 29           24000.0            24000
# 30           24000.0            24000
# 31           24000.0            24000
# 32           23998.0            23998
# 33           23998.0            23998
# 34           23998.0            23998
# 35           14998.0            14998
# 36           14998.0            14998
# 37           14998.0            14998
# 38           14998.0            14998
# 39           14998.0            14998
# 40           14399.0            14399
# 41           14399.0            14399

# %%
# 15 courses: 1.5 hours
# 18 courses: 1 hour
# 2 courses: half hour

# %% [markdown]
# # Cache single session tracking for id consistency

# %%
# sample_course = '17214B'
# sample_session = 'classinsight-cmu_17214B_ph_a21_201905011030-front'
# sample_session_dir = frame_file_data[sample_course][sample_session]['dir_location']
# sample_frame_ids = frame_file_data[sample_course][sample_session]['frame_ids']
# sample_session_dir

# %%
# session_tracking_ids = {}
# for frame_id in sample_frame_ids:
#     frame_data = pickle.load(open(f'{sample_session_dir}/{frame_id}.pb','rb'))
#     frame_tracking_ids = [xr['track_id'] for xr in frame_data[1]]
#     # print(frame_id, frame_tracking_ids)
#     session_tracking_ids[frame_id] = {int(xr):1 for xr in frame_tracking_ids}
# df_session_ids = pd.DataFrame.from_dict(session_tracking_ids)

# %%
# df_session_ids.head()

# %%
# np.unique(np.nansum(df_session_ids.values,axis=1) // 5, return_counts=True)

# %%
session_tracking_cache = '../cache/analysis_tracking/session_tracking_info'

# %%
unfinished_sessions = []
for course_idx, course in enumerate(frame_file_data):
    for session_idx, session_id in enumerate(frame_file_data[course]):
        session_tracking_cache_file = f"{session_tracking_cache}/{session_id}.pb"
        try:
            if not os.path.exists(session_tracking_cache_file):
                session_dir = frame_file_data[course][session_id]['dir_location']
                frame_ids = frame_file_data[course][session_id]['frame_ids']
                session_tracking_ids = {}
                for frame_id in frame_ids:
                    frame_data = pickle.load(open(f'{session_dir}/{frame_id}.pb','rb'))
                    frame_tracking_ids = [xr['track_id'] for xr in frame_data[1]]
                    # print(frame_id, frame_tracking_ids)
                    session_tracking_ids[frame_id] = {int(xr):1 for xr in frame_tracking_ids}
                df_session_ids = pd.DataFrame.from_dict(session_tracking_ids)
                pickle.dump(df_session_ids, open(session_tracking_cache_file,'wb'))
                print(f"Got tracking info for session: {course_idx}-{course}, session:{session_idx}-{session_id}")
            else:
                ...
                # print(f"FILE EXISTS: tracking info for session: {course_idx}-{course}, session:{session_idx}-{session_id}")
        except:
            print(f"ERROR: Unable to get session tracking for: {course_idx}-{course}, session:{session_idx}-{session_id}")
            unfinished_sessions.append((course, session_id))
            print(traceback.format_exc())
# Out:
# Got tracking info for session: 45-05772A, session:1-classinsight-cmu_05772A_ghc_4301_201902051030-front
# Got tracking info for session: 45-05772A, session:3-classinsight-cmu_05772A_ghc_4301_201902121030-front
# Got tracking info for session: 46-09105A, session:0-classinsight-cmu_09105A_ghc_4102_201901291830-front
# Got tracking info for session: 46-09105A, session:11-classinsight-cmu_09105A_ghc_4102_201903071830-front
# Got tracking info for session: 46-09105A, session:12-classinsight-cmu_09105A_ghc_4102_201903121830-front
# Got tracking info for session: 46-09105A, session:15-classinsight-cmu_09105A_ghc_4102_201903211830-front
# Got tracking info for session: 46-09105A, session:27-classinsight-cmu_09105A_ghc_4102_201905021830-front
# Got tracking info for session: 47-09105C, session:1-classinsight-cmu_09105C_ghc_5222_201905021830-front
# Got tracking info for session: 47-09105C, session:3-classinsight-cmu_09105C_ghc_5222_201902051830-front
# Got tracking info for session: 47-09105C, session:5-classinsight-cmu_09105C_ghc_5222_201902121830-front
# Got tracking info for session: 47-09105C, session:14-classinsight-cmu_09105C_ghc_5222_201903141830-front
# Got tracking info for session: 47-09105C, session:18-classinsight-cmu_09105C_ghc_5222_201904301830-front
# Got tracking info for session: 47-09105C, session:20-classinsight-cmu_09105C_ghc_5222_201903281830-front
# Got tracking info for session: 47-09105C, session:23-classinsight-cmu_09105C_ghc_5222_201904091830-front
# Got tracking info for session: 47-09105C, session:28-classinsight-cmu_09105C_ghc_5222_201901241830-front
# Got tracking info for session: 48-09105D, session:0-classinsight-cmu_09105D_ghc_5222_201901291930-front
# Got tracking info for session: 48-09105D, session:1-classinsight-cmu_09105D_ghc_5222_201901311930-front
# Got tracking info for session: 48-09105D, session:3-classinsight-cmu_09105D_ghc_5222_201902071930-front
# Got tracking info for session: 48-09105D, session:6-classinsight-cmu_09105D_ghc_5222_201901241930-front
# Got tracking info for session: 48-09105D, session:8-classinsight-cmu_09105D_ghc_5222_201904301930-front
# Got tracking info for session: 48-09105D, session:12-classinsight-cmu_09105D_ghc_5222_201904181930-front
# Got tracking info for session: 48-09105D, session:23-classinsight-cmu_09105D_ghc_5222_201903281930-front
# Got tracking info for session: 48-09105D, session:24-classinsight-cmu_09105D_ghc_5222_201904021930-front
# Got tracking info for session: 48-09105D, session:28-classinsight-cmu_09105D_ghc_5222_201904161930-front
# Got tracking info for session: 49-15251C, session:0-classinsight-cmu_15251C_weh_5310_201902011130-front
# Got tracking info for session: 49-15251C, session:1-classinsight-cmu_15251C_weh_5310_201902081130-front
# Got tracking info for session: 49-15251C, session:8-classinsight-cmu_15251C_weh_5310_201904051130-front
# Got tracking info for session: 49-15251C, session:10-classinsight-cmu_15251C_weh_5310_201904191130-front
# Got tracking info for session: 49-15251C, session:11-classinsight-cmu_15251C_weh_5310_201904261130-front
# Got tracking info for session: 50-15251I, session:5-classinsight-cmu_15251I_weh_6423_201903080930-front
# Got tracking info for session: 50-15251I, session:7-classinsight-cmu_15251I_weh_6423_201903220930-front
# Got tracking info for session: 51-17346A, session:0-classinsight-cmu_17346A_weh_4623_201904021230-front
# Got tracking info for session: 51-17346A, session:2-classinsight-cmu_17346A_weh_4623_201904161230-front
# Got tracking info for session: 51-17346A, session:4-classinsight-cmu_17346A_weh_4623_201904301230-front
# Got tracking info for session: 52-17356A, session:1-classinsight-cmu_17356A_weh_4623_201901241230-front
# Got tracking info for session: 52-17356A, session:4-classinsight-cmu_17356A_weh_4623_201902261230-front
# Got tracking info for session: 52-17356A, session:8-classinsight-cmu_17356A_weh_4623_201903261230-front
# Got tracking info for session: 53-21127H, session:2-classinsight-cmu_21127H_ph_a18c_201903051530-front
# Got tracking info for session: 53-21127H, session:5-classinsight-cmu_21127H_ph_a18c_201903141530-front
# Got tracking info for session: 53-21127H, session:12-classinsight-cmu_21127H_ph_a18c_201902211530-front
# Got tracking info for session: 53-21127H, session:13-classinsight-cmu_21127H_ph_a18c_201903191530-front
# Got tracking info for session: 53-21127H, session:18-classinsight-cmu_21127H_ph_a18c_201904041530-front
# Got tracking info for session: 53-21127H, session:20-classinsight-cmu_21127H_ph_a18c_201904091530-front
# Got tracking info for session: 53-21127H, session:21-classinsight-cmu_21127H_ph_a18c_201904111530-front
# Got tracking info for session: 53-21127H, session:26-classinsight-cmu_21127H_ph_a18c_201904251530-front
# Got tracking info for session: 54-17356L1, session:1-classinsight-cmu_17356L1_weh_5302_201902051030-front
# Got tracking info for session: 54-17356L1, session:7-classinsight-cmu_17356L1_weh_5302_201902121030-front
# Got tracking info for session: 54-17356L1, session:10-classinsight-cmu_17356L1_weh_5302_201903071030-front
# Got tracking info for session: 54-17356L1, session:15-classinsight-cmu_17356L1_weh_5302_201903261030-front
# Got tracking info for session: 54-17356L1, session:19-classinsight-cmu_17356L1_weh_5302_201904091030-front
# Got tracking info for session: 54-17356L1, session:20-classinsight-cmu_17356L1_weh_5302_201904111030-front
# Got tracking info for session: 54-17356L1, session:27-classinsight-cmu_17356L1_weh_5302_201905021030-front

# %% [markdown]
# # Setup tracking id experiment by random selection of courses, sessions and snippets

# %%
df_session_info.head()
# Out:
#    course                                      session          start_time  \
# 0  17214B  classinsight-cmu_17214B_ph_a21_201905011030 2019-05-01 10:30:00
# 1  17214B  classinsight-cmu_17214B_ph_a21_201905011030 2019-05-01 10:30:00
# 2  17214B  classinsight-cmu_17214B_ph_a21_201905011030 2019-05-01 10:30:00
# 3  17214B  classinsight-cmu_17214B_ph_a21_201905011030 2019-05-01 10:30:00
# 4  17214B  classinsight-cmu_17214B_ph_a21_201905011030 2019-05-01 10:30:00
#
#   start_hour classroom  completed  num_frames  max_frame  duration_in_mins  \
# 0      10:30    ph_a21       True       14999    44994.0              49.0
# 1      10:30    ph_a21       True       14999    44994.0              49.0
# 2      10:30    ph_a21       True       14999    44994.0              49.0
# 3      10:30    ph_a21       True       14999    44994.0              49.0
# 4      10:30    ph_a21       True       14999    44994.0              49.0
#
#    course_num  S.No Semester                    Division Dept  \
# 0       17214     9     Fall  School of Computer Science  ISR
# 1       17214    28   Spring  School of Computer Science   SE
# 2       17214     9     Fall  School of Computer Science  ISR
# 3       17214    28   Spring  School of Computer Science   SE
# 4       17214     9     Fall  School of Computer Science  ISR
#
#             course_name   Course Level  Hrs Per Week course_category  \
# 0  PRIN 0-0 SFTWR CONST  Undergraduate         14.51         applied
# 1  PRIN 0-0 SFTWR CONST  Undergraduate         13.09         applied
# 2  PRIN 0-0 SFTWR CONST  Undergraduate         14.51         applied
# 3  PRIN 0-0 SFTWR CONST  Undergraduate         13.09         applied
# 4  PRIN 0-0 SFTWR CONST  Undergraduate         14.51         applied
#
#                                          description  \
# 0  Software engineers today are less likely to de...
# 1  Software engineers today are less likely to de...
# 2  Software engineers today are less likely to de...
# 3  Software engineers today are less likely to de...
# 4  Software engineers today are less likely to de...
#
#    Interest in student learning  Clearly explain course requirements  \
# 0                          4.27                                 4.24
# 1                          4.39                                 4.18
# 2                          4.27                                 4.24
# 3                          4.39                                 4.18
# 4                          4.27                                 4.24
#
#    Clear learning objectives & goals  \
# 0                               4.38
# 1                               4.48
# 2                               4.38
# 3                               4.48
# 4                               4.38
#
#    Instructor provides feedback to students to improve  \
# 0                                               4.04
# 1                                               3.88
# 2                                               4.04
# 3                                               3.88
# 4                                               4.04
#
#    Demonstrate importance of subject matter  \
# 0                                      4.36
# 1                                      4.51
# 2                                      4.36
# 3                                      4.51
# 4                                      4.36
#
#    Explains subject matter of course  Show respect for all students  \
# 0                               4.16                           4.40
# 1                               4.38                           4.86
# 2                               4.16                           4.40
# 3                               4.38                           4.86
# 4                               4.16                           4.40
#
#    Overall teaching rate  Overall course rate
# 0                   4.13                 4.13
# 1                   4.26                 4.26
# 2                   4.13                 4.13
# 3                   4.26                 4.26
# 4                   4.13                 4.13

# %%
# randomly select 10 courses.
np.random.seed(43)
prefiltered_courses = df_session_info.course.drop_duplicates().sample(n=10)
print(f"Prefiltered courses:{prefiltered_courses}")

# select 5 sessions per course 
df_prefiltered_sessions = pd.DataFrame()
for course in prefiltered_courses.values:
    if df_session_info[df_session_info.course==course].shape[0]>5:
        df_prefiltered_sessions.append(df_session_info[df_session_info.course==course].sample(n=5))
df_prefiltered_sessions
# Out:
# Prefiltered courses:541     79388A
# 127     05410B
# 597     12411B
# 753     36200S
# 155     21127J
# 676     09105D
# 239     21127L
# 851     76270S
# 619     09105A
# 1120    17346A
# Name: course, dtype: object
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_prefiltered_sessions
# Out:
# Empty DataFrame
# Columns: []
# Index: []
